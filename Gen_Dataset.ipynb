# %%
import yfinance as yf
import pandas as pd

# %%
def gen_dataset(ticker_pair, start_date, end_date):
    dataset = []
    for pair in ticker_pair:
        ticker_data = {}
        data = yf.download(tickers=pair, start=start_date, end=end_date)
        for col in data.columns:
            ticker_data['currency'] = [pair]*len(data)
            ticker_data['date'] = data[col].index
            ticker_data[col[0]] = data[col].values
        ticker_df = pd.DataFrame(ticker_data)
        
        dataset.append(ticker_df)

    dataset_df = pd.concat(dataset, ignore_index=True)

    return dataset_df

# %%
start_date = '2015-01-05'
end_date = '2024-12-28'
pairs = ['EURUSD=X', 'VND=X', 'BTC-USD']
dataset_df = gen_dataset(ticker_pair=pairs, start_date=start_date, end_date=end_date)
dataset_df.loc[dataset_df['currency']=='EURUSD=X', 'currency'] = 'EUR-USD'
dataset_df.loc[dataset_df['currency']=='VND=X', 'currency'] = 'USD-VND'
dataset_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#      currency       date         Close          High           Low  \
# 0     EUR-USD 2015-01-05      1.194643      1.197590      1.188909
# 1     EUR-USD 2015-01-06      1.193902      1.197000      1.188693
# 2     EUR-USD 2015-01-07      1.187536      1.190000      1.180401
# 3     EUR-USD 2015-01-08      1.183600      1.184806      1.175601
# 4     EUR-USD 2015-01-09      1.179607      1.183830      1.176831
# ...       ...        ...           ...           ...           ...
# 8846  BTC-USD 2024-12-23  94686.242188  96416.210938  92403.132812
# 8847  BTC-USD 2024-12-24  98676.093750  99404.062500  93448.015625
# 8848  BTC-USD 2024-12-25  99299.195312  99478.750000  97593.468750
# 8849  BTC-USD 2024-12-26  95795.515625  99884.570312  95137.882812
# ...

# %%
dataset_df.to_csv('yfinance_data.csv', index=False)
